# %%
# %load ~/ipyhead
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# We're going to load quantification data from Kallisto. We used the index: `Homo_sapiens.GRCh38.cdna.all.kallisto.idx`
#
# Per http://f1000research.com/articles/4-1521/v2 (https://github.com/mikelove/tximport), we should use TPM (not estimated counts, which are sensitive to transcript length) and aggregate to gene level.
#
# Here is how to annotate with gene names in Python: https://github.com/hammerlab/cohorts/blob/master/cohorts/load.py#L797-L801
#
# We made the index by downloading from http://ftp.ensembl.org/pub/release-79/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz , which is the same as what's suggested on kallisto website. So use release 79.
#
# Though note that the newest release is release 85, from ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/README_ensembl:
#
# ```
# #tax_id	ncbi_release	ncbi_assembly	ensembl_release	ensembl_assembly	date_compared
# 9606	Homo sapiens Annotation Release 108	GRCh38.p7	85	GRCh38.p7	20160801
# ```
#
# And http://ftp.ensembl.org/pub/release-85/fasta/homo_sapiens/cdna/ has different files.

# %%
df = pd.read_csv('data/output/ERR431572/abundance.tsv', sep='\t')
df.head()
# Out:
#          target_id  length  eff_length  est_counts  tpm
# 0  ENST00000415118       8     5.14286         0.0  0.0
# 1  ENST00000448914      13     7.08333         0.0  0.0
# 2  ENST00000434970       9     6.14286         0.0  0.0
# 3  ENST00000390577      37    16.14290         0.0  0.0
# 4  ENST00000437320      19    12.00000         0.0  0.0

# %%
# !pip install pyensembl
# Out:
# Requirement already satisfied (use --upgrade to upgrade): pyensembl in /home/maxim/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): memoized-property>=1.0.2 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): serializable in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): pandas>=0.15 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): typechecks>=0.0.2 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): datacache>=0.4.16 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): gtfparse>=0.0.3 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.9.0 in /home/maxim/anaconda2/lib/python2.7/site-packages (from pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): simplejson in /home/maxim/anaconda2/lib/python2.7/site-packages (from serializable->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /home/maxim/anaconda2/lib/python2.7/site-packages (from pandas>=0.15->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /home/maxim/anaconda2/lib/python2.7/site-packages (from pandas>=0.15->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): requests>=2.5.1 in /home/maxim/anaconda2/lib/python2.7/site-packages (from datacache>=0.4.16->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): appdirs>=1.4.0 in /home/maxim/anaconda2/lib/python2.7/site-packages (from datacache>=0.4.16->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): progressbar33>=2.4 in /home/maxim/anaconda2/lib/python2.7/site-packages (from datacache>=0.4.16->pyensembl)
# Requirement already satisfied (use --upgrade to upgrade): biopython>=1.65 in /home/maxim/anaconda2/lib/python2.7/site-packages (from datacache>=0.4.16->pyensembl)
# You are using pip version 8.1.1, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pyensembl install --release 79 --species human
# Out:
# -- Running 'install' for EnsemblRelease(release=79, species='homo_sapiens')
# INFO:root:Fetching /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.gz from URL ftp://ftp.ensembl.org/pub/release-79/gtf/homo_sapiens/Homo_sapiens.GRCh38.79.gtf.gz
# Downloading ftp://ftp.ensembl.org/pub/release-79/gtf/homo_sapiens/Homo_sapiens.GRCh38.79.gtf.gz to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.gz
# INFO:root:Fetching /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.cdna.all.fa.gz from URL ftp://ftp.ensembl.org/pub/release-79/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
# Downloading ftp://ftp.ensembl.org/pub/release-79/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.cdna.all.fa.gz
# INFO:root:Fetching /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.pep.all.fa.gz from URL ftp://ftp.ensembl.org/pub/release-79/fasta/homo_sapiens/pep/Homo_sapiens.GRCh38.pep.all.fa.gz
# Downloading ftp://ftp.ensembl.org/pub/release-79/fasta/homo_sapiens/pep/Homo_sapiens.GRCh38.pep.all.fa.gz to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.pep.all.fa.gz
# Creating database: /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.db
# Reading GTF from /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.gz
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_version', 'gene_name', 'gene_source', 'gene_biotype', 'transcript_id', 'transcript_version', 'transcript_name', 'transcript_source', 'transcript_biotype', 'tag', 'transcript_support_level', 'exon_number', 'exon_id', 'exon_version', 'ccds_id', 'protein_id', 'protein_version']
# Saving DataFrame to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.expanded.csv
# INFO:root:Creating database /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.79.gtf.db containing: gene, Selenocysteine, UTR, exon, stop_codon, CDS, start_codon, transcript
# INFO:root:Running sqlite query: "CREATE TABLE gene (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT UNIQUE PRIMARY KEY NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 65217 rows into table gene
# INFO:root:Creating index on gene (seqname, start, end)
# INFO:root:Creating index on gene (seqname, start, end, strand)
# INFO:root:Creating index on gene (gene_name)
# INFO:root:Creating index on gene (transcript_id)
# INFO:root:Creating index on gene (transcript_name)
# INFO:root:Creating index on gene (exon_id)
# INFO:root:Creating index on gene (protein_id)
# INFO:root:Creating index on gene (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE Selenocysteine (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 114 rows into table Selenocysteine
# INFO:root:Creating index on Selenocysteine (seqname, start, end)
# INFO:root:Creating index on Selenocysteine (seqname, start, end, strand)
# INFO:root:Creating index on Selenocysteine (gene_name)
# INFO:root:Creating index on Selenocysteine (gene_id)
# INFO:root:Creating index on Selenocysteine (transcript_id)
# INFO:root:Creating index on Selenocysteine (transcript_name)
# INFO:root:Creating index on Selenocysteine (exon_id)
# INFO:root:Creating index on Selenocysteine (protein_id)
# INFO:root:Creating index on Selenocysteine (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE UTR (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 290327 rows into table UTR
# INFO:root:Creating index on UTR (seqname, start, end)
# INFO:root:Creating index on UTR (seqname, start, end, strand)
# INFO:root:Creating index on UTR (gene_name)
# INFO:root:Creating index on UTR (gene_id)
# INFO:root:Creating index on UTR (transcript_id)
# INFO:root:Creating index on UTR (transcript_name)
# INFO:root:Creating index on UTR (exon_id)
# INFO:root:Creating index on UTR (protein_id)
# INFO:root:Creating index on UTR (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE exon (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 1259629 rows into table exon
# INFO:root:Creating index on exon (seqname, start, end)
# INFO:root:Creating index on exon (seqname, start, end, strand)
# INFO:root:Creating index on exon (gene_name)
# INFO:root:Creating index on exon (gene_id)
# INFO:root:Creating index on exon (transcript_id)
# INFO:root:Creating index on exon (transcript_name)
# INFO:root:Creating index on exon (exon_id)
# INFO:root:Creating index on exon (protein_id)
# INFO:root:Creating index on exon (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE stop_codon (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 69998 rows into table stop_codon
# INFO:root:Creating index on stop_codon (seqname, start, end)
# INFO:root:Creating index on stop_codon (seqname, start, end, strand)
# INFO:root:Creating index on stop_codon (gene_name)
# INFO:root:Creating index on stop_codon (gene_id)
# INFO:root:Creating index on stop_codon (transcript_id)
# INFO:root:Creating index on stop_codon (transcript_name)
# INFO:root:Creating index on stop_codon (exon_id)
# INFO:root:Creating index on stop_codon (protein_id)
# INFO:root:Creating index on stop_codon (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE CDS (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 751742 rows into table CDS
# INFO:root:Creating index on CDS (seqname, start, end)
# INFO:root:Creating index on CDS (seqname, start, end, strand)
# INFO:root:Creating index on CDS (gene_name)
# INFO:root:Creating index on CDS (gene_id)
# INFO:root:Creating index on CDS (transcript_id)
# INFO:root:Creating index on CDS (transcript_name)
# INFO:root:Creating index on CDS (exon_id)
# INFO:root:Creating index on CDS (protein_id)
# INFO:root:Creating index on CDS (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE start_codon (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 69881 rows into table start_codon
# INFO:root:Creating index on start_codon (seqname, start, end)
# INFO:root:Creating index on start_codon (seqname, start, end, strand)
# INFO:root:Creating index on start_codon (gene_name)
# INFO:root:Creating index on start_codon (gene_id)
# INFO:root:Creating index on start_codon (transcript_id)
# INFO:root:Creating index on start_codon (transcript_name)
# INFO:root:Creating index on start_codon (exon_id)
# INFO:root:Creating index on start_codon (protein_id)
# INFO:root:Creating index on start_codon (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE transcript (seqname TEXT NOT NULL, source TEXT NOT NULL, feature TEXT NOT NULL, start INT NOT NULL, end INT NOT NULL, score FLOAT, strand TEXT NOT NULL, frame TEXT NOT NULL, gene_id TEXT NOT NULL, gene_version TEXT NOT NULL, gene_name TEXT NOT NULL, gene_source TEXT NOT NULL, gene_biotype TEXT NOT NULL, transcript_id TEXT UNIQUE PRIMARY KEY NOT NULL, transcript_version TEXT NOT NULL, transcript_name TEXT NOT NULL, transcript_source TEXT NOT NULL, transcript_biotype TEXT NOT NULL, tag TEXT NOT NULL, transcript_support_level TEXT NOT NULL, exon_number TEXT NOT NULL, exon_id TEXT NOT NULL, exon_version TEXT NOT NULL, ccds_id TEXT NOT NULL, protein_id TEXT NOT NULL, protein_version TEXT NOT NULL)"
# INFO:root:Inserting 213622 rows into table transcript
# INFO:root:Creating index on transcript (seqname, start, end)
# INFO:root:Creating index on transcript (seqname, start, end, strand)
# INFO:root:Creating index on transcript (gene_name)
# INFO:root:Creating index on transcript (gene_id)
# INFO:root:Creating index on transcript (transcript_name)
# INFO:root:Creating index on transcript (exon_id)
# INFO:root:Creating index on transcript (protein_id)
# INFO:root:Creating index on transcript (ccds_id)
# INFO:root:Running sqlite query: "CREATE TABLE _datacache_metadata (version INT)"
# INFO:root:Running sqlite query: "INSERT INTO _datacache_metadata VALUES (2)"
# INFO:root:Parsing sequences from FASTA file at /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.cdna.all.fa.gz
# INFO:root:Saving sequence dictionary to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.cdna.all.fa.gz.pickle
# INFO:root:Parsing sequences from FASTA file at /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.pep.all.fa.gz
# INFO:root:Saving sequence dictionary to /home/maxim/.cache/pyensembl/GRCh38/ensembl79/Homo_sapiens.GRCh38.pep.all.fa.gz.pickle

# %%
from pyensembl import cached_release

# %%
ensembl_release = cached_release(79)
df['sample_id'] = 1
df['gene_name'] = df['target_id'].map(lambda t: ensembl_release.gene_name_of_transcript_id(t))

# %%
# sum counts, abundance (tpm) across genes
simple_summary = df.groupby(['sample_id', 'gene_name'])[['est_counts', 'tpm']].sum().reset_index()
simple_summary.to_csv('data/summary.simple.tsv', sep='\t', index=None)
simple_summary.head()
# Out:
#    sample_id gene_name  est_counts        tpm
# 0          1      A1BG   80.232280  11.155641
# 1          1      A1CF   18.042401   0.382263
# 2          1       A2M    3.000000   1.226161
# 3          1     A2ML1   21.912401   2.756862
# 4          1     A2MP1    2.000000   0.092441

# %% [markdown]
# Scale the TPM, as in that paper:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173259 entries, 0 to 173258
# Data columns (total 7 columns):
# target_id     173259 non-null object
# length        173259 non-null int64
# eff_length    173259 non-null float64
# est_counts    173259 non-null float64
# tpm           173259 non-null float64
# sample_id     173259 non-null int64
# gene_name     173259 non-null object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 9.3+ MB

# %%
# eff_length is the right one to use.
any(pd.isnull(df.length)), any(pd.isnull(df.eff_length))
# Out:
# (False, False)

# %% [markdown]
# How to summarize tpm, from https://github.com/mikelove/tximport/blob/master/R/tximport.R
#
# abundanceMat is from tpm. lengthMat is from eff_length. countsMat is from est_counts. These are gene-level.
# Any mat Tx is transcript-level.
#
# ```
#   # summarize abundance and counts
#   message("summarizing abundance")
#   abundanceMat <- rowsum(abundanceMatTx, geneId)
#   message("summarizing counts")
#   countsMat <- rowsum(countsMatTx, geneId)
#   message("summarizing length")
#
#   # the next lines calculate a weighted average of transcript length,
#   # weighting by transcript abundance.
#   # this can be used as an offset / normalization factor which removes length bias
#   # for the differential analysis of estimated counts summarized at the gene level.
#   weightedLength <- rowsum(abundanceMatTx * lengthMatTx, geneId)
#   lengthMat <- weightedLength / abundanceMat
#
#   # pre-calculate a simple average transcript length
#   # for the case the abundances are all zero for all samples.
#   # first, average the tx lengths over samples
#   aveLengthSamp <- rowMeans(lengthMatTx)
#   # then simple average of lengths within genes (not weighted by abundance)
#   aveLengthSampGene <- tapply(aveLengthSamp, geneId, mean)
#
#   stopifnot(all(names(aveLengthSampGene) == rownames(lengthMat)))
#
#   # check for NaN and if possible replace these values with geometric mean of other samples.
#   # (the geometic mean here implies an offset of 0 on the log scale)
#   # NaN come from samples which have abundance of 0 for all isoforms of a gene, and
#   # so we cannot calculate the weighted average. our best guess is to use the average
#   # transcript length from the other samples.
#   lengthMat <- replaceMissingLength(lengthMat, aveLengthSampGene)
#
#   if (countsFromAbundance != "no") {
#     countsSum <- colSums(countsMat)
#     if (countsFromAbundance == "lengthScaledTPM") {
#       newCounts <- abundanceMat * rowMeans(lengthMat)
#     } else {
#         newCounts <- abundanceMat
#       }
#     newSum <- colSums(newCounts)
#     countsMat <- t(t(newCounts) * (countsSum/newSum))
#   }
#     return(list(abundance=abundanceMat, counts=countsMat, length=lengthMat,
#               countsFromAbundance=countsFromAbundance))
#
#
# # function for replacing missing average transcript length values
# replaceMissingLength <- function(lengthMat, aveLengthSampGene) {
#   nanRows <- which(apply(lengthMat, 1, function(row) any(is.nan(row))))
#   if (length(nanRows) > 0) {
#     for (i in nanRows) {
#       if (all(is.nan(lengthMat[i,]))) {
#         # if all samples have 0 abundances for all tx, use the simple average
#         lengthMat[i,] <- aveLengthSampGene[i]
#       } else {
#           # otherwise use the geometric mean of the lengths from the other samples
#           idx <- is.nan(lengthMat[i,])
#           lengthMat[i,idx] <-  exp(mean(log(lengthMat[i,!idx]), na.rm=TRUE))
#         }
#     }
#   }
#   lengthMat
# }
#
#
# ```
#
# Note how the matrices are set up:
#
# * rows: transcripts (n)
# * columns: samples (m)
#
# In R:
# * rowSums returns n*1 -- i.e. sums columns in every row
# * colSums return 1*m: i.e. sums all rows for every column
# * similarly, rowMeans returns n*1: takes mean of values in each row.
# * similarly, colMeans returns m*1: takes mean of values in each column.
#
# ```
# > x <- cbind(x1 = 3, x2 = c(4:1, 2:5))
# > x
#      x1 x2
# [1,]  3  4
# [2,]  3  3
# [3,]  3  2
# [4,]  3  1
# [5,]  3  2
# [6,]  3  3
# [7,]  3  4
# [8,]  3  5
# > rowSums(x)
# [1] 7 6 5 4 5 6 7 8
# > colSums(x)
# x1 x2
# 24 24
# > rowMeans(x)
# [1] 3.5 3.0 2.5 2.0 2.5 3.0 3.5 4.0
# > colMeans(x)
# x1 x2
#  3  3
# ```
#
# but:
#
# * rowsum(x, group) means take vertical (column) sums across rows for each value of a grouping variable. returns k (number of groups) * m.
#
# ```
# > require(stats)
# > x <- matrix(runif(100), ncol = 5)
# > x
#             [,1]       [,2]        [,3]       [,4]       [,5]
#  [1,] 0.92193476 0.64068964 0.590930078 0.22589474 0.94385005
#  [2,] 0.15434593 0.35520130 0.891485406 0.01536309 0.23128203
#  [3,] 0.65030467 0.56747106 0.583187841 0.50184454 0.25598191
#  [4,] 0.08740973 0.77858838 0.001003955 0.09488344 0.40001838
#  [5,] 0.59932257 0.10921583 0.202659336 0.99391111 0.05304302
#  [6,] 0.37518234 0.15261407 0.201251270 0.39387585 0.06438196
#  [7,] 0.64699723 0.81092956 0.888885059 0.91184237 0.68612899
#  [8,] 0.83465129 0.23701509 0.182450580 0.94085281 0.55303249
#  [9,] 0.67748311 0.39298104 0.743816100 0.04000909 0.04451748
# [10,] 0.36702365 0.51603955 0.676513819 0.21491027 0.97969625
# [11,] 0.81330661 0.01567229 0.265442836 0.33373162 0.03803008
# [12,] 0.42658481 0.73068255 0.072104913 0.64861247 0.49143138
# [13,] 0.68161538 0.11003679 0.066483887 0.95039580 0.78276828
# [14,] 0.57063695 0.85563269 0.517796875 0.11461768 0.36473195
# [15,] 0.89833696 0.53448586 0.053799714 0.35298232 0.71251391
# [16,] 0.93033111 0.98725333 0.743280945 0.70274502 0.91984371
# [17,] 0.72468190 0.80205415 0.304485959 0.51483852 0.03668938
# [18,] 0.29001996 0.60153044 0.976458703 0.72192388 0.14789380
# [19,] 0.46333744 0.25058092 0.471588748 0.05430856 0.10111760
# [20,] 0.78955687 0.94806861 0.675796005 0.87945982 0.77918547
# > group <- sample(1:8, 20, TRUE)
# > group
#  [1] 5 4 3 5 5 7 8 5 6 4 2 4 5 5 1 4 4 3 3 3
# > (xsum <- rowsum(x, group))
#        [,1]       [,2]       [,3]       [,4]       [,5]
# 1 0.8983370 0.53448586 0.05379971 0.35298232 0.71251391
# 2 0.8133066 0.01567229 0.26544284 0.33373162 0.03803008
# 3 2.1932189 2.36765104 2.70703130 2.15753680 1.28417877
# 4 2.6029674 3.39123087 2.68787104 2.09646937 2.65894275
# 5 3.6955707 2.73117843 1.56132471 3.32055558 3.09744417
# 6 0.6774831 0.39298104 0.74381610 0.04000909 0.04451748
# 7 0.3751823 0.15261407 0.20125127 0.39387585 0.06438196
# 8 0.6469972 0.81092956 0.88888506 0.91184237 0.68612899
# ```

# %%
# reimplement R, but keep in tidy form: samples are not columns anymore, we have sample ID column instead

abundanceMat = df.groupby(['sample_id', 'gene_name'])[['tpm']].sum()
df_tmp = df.copy()
df_tmp['weightedLength'] = df_tmp['tpm'] * df_tmp['eff_length']
weightedLength = df_tmp.groupby(['sample_id', 'gene_name'])[['weightedLength']].sum()
lengthMat = (weightedLength['weightedLength']/ abundanceMat['tpm']).reset_index()
# make wide again: make the samples be columns. n_genes x n_samples, values are lengths
lengthMat = lengthMat.pivot( index='gene_name', columns='sample_id', values=0)

## replace missing average transcript length values

# first, calculate average transcript length *across samples* for each transcript
# but keep gene name in there
aveLengthSamp = df.groupby('target_id')[['eff_length', 'gene_name']].agg({
        'eff_length': 'mean',
        'gene_name': 'first'
    })
# second, take simple average of lengths within genes, without weighting by abundance
# i.e. aggregate those averages by gene now
aveLengthSampGene = aveLengthSamp.groupby('gene_name').eff_length.mean()

# do the replacement
nanRows = lengthMat[lengthMat.isnull().any(axis=1)].index # np.where(pd.isnull(lengthMat))[0] # row indices where null
for row_idx in nanRows:
    if all(pd.isnull(lengthMat.loc[row_idx])):
        # use simple average
        lengthMat.loc[row_idx] = aveLengthSampGene.loc[row_idx] # lengthMat.index[row_idx] # look up by gene name
    else:
        # use geometric mean of lengths from other samples
        null_indices = np.where(pd.isnull(lengthMat.loc[row_idx]))[0]
        others = np.where(~pd.isnull(lengthMat.loc[row_idx]))[0]
        lengthMat.loc[row_idx, null_indices] = np.exp(np.mean(np.log(lengthMat.loc[row_idx, others])))
assert not pd.isnull(lengthMat).any().bool()

# %%
# length scaled TPM
counts_LS = abundanceMat

# %%
# either scaledTPM or lengthScaledTPM

def scaledTPM(matrix):
    
    pass
def lengthScaledTPM(matrix):
    pass

def core(matrix):
    pass
abundanceMat = df.groupby(['sample_id', 'gene_name'])[['tpm']].sum()#.reset_index()
df_tmp = df.copy()
df_tmp['weightedLength'] = df_tmp['tpm'] * df_tmp['eff_length']
weightedLength = df_tmp.groupby(['sample_id', 'gene_name'])[['weightedLength']].sum()#.reset_index()
lengthMat = (weightedLength['weightedLength']/ abundanceMat['tpm']).reset_index()

# replace missing average transcript length values
# first, calculate average transcript length *across samples*


# replace for case where abundances are all 0 for all samples

# function for replacing missing average transcript length values
def replaceMissingLength(df, aveLengthSampGene):
    lengthMat = df.copy()
    nanRows = np.where(pd.isnull(lengthMat))[0] # row indices where null
    for row_idx in nanRows:
        if all(pd.isnull(lengthMat[row_idx])):
            # use simple average
            lengthMat.loc[row_idx] = aveLengthSampGene[row_idx]
        else:
            # use geometric mean of lengths from other samples
            null_indices = np.where(pd.isnull(lengthMat[row_idx]))
            others = np.where(~pd.isnull(lengthMat[row_idx]))
            lengthMath.loc[row_idx, null_indices] = np.exp(np.mean(np.log(lengthMat[row_idx, others])))
        
    return lengthMat
# Out:
# (                        weightedLength
#  sample_id gene_name
#  1         A1BG            12330.780428
#            A1CF             1938.386555
#            A2M                 0.000000
#            A2ML1            2277.117735
#            A2MP1             275.504952
#            A3GALT2           413.259230
#            A4GALT            688.761456
#            A4GNT               0.000000
#            AAAS             4683.586265
#            AACS            22349.414328
#            AACSP1           1229.235312
#            AADAC               0.000000
#            AADACL2             0.000000
#            AADACL3           275.505086
#            AADACL4           413.256817
#            AADACP1             0.000000
#            AADAT             137.752799
#            AAED1           41436.691593
#            AAGAB           64055.062744
#            AAK1            21099.125589
#            AAMDC            5703.541360
#            AAMP            47800.183318
#            AANAT            4008.740330
#            AAR2            15637.176032
#            AARD             1931.891835
#            AARS            21027.261607
#            AARS2           14123.554899
#            AARSD1          26668.543935
#            AARSP1              0.000000
#            AASDH            9229.434182
#  ...                                ...
#            ZSWIM7           6247.362860
#            ZSWIM8         244052.835619
#            ZUFSP           57993.891116
#            ZW10             4270.334216
#            ZWILCH           7670.554086
#            ZWINT             137.753381
#            ZXDA            15370.314164
#            ZXDB            75270.822958
#            ZXDC            35953.437002
#            ZYG11A           8997.642869
#            ZYG11AP1            0.000000
#            ZYG11B          35897.976431
#            ZYX             97529.020762
#            ZZEF1          308009.997360
#            ZZZ3            38424.735589
#            bP-21201H5.1      419.842982
#            bP-21264C1.1      275.505532
#            bP-21264C1.3        0.000000
#            bP-2168N6.1         0.000000
#            bP-2168N6.2         0.000000
#            bP-2168N6.3         0.000000
#            bP-2171C21.2        0.000000
#            bP-2171C21.4        0.000000
#            bP-2171C21.5      240.202699
#            bP-2171C21.6        0.000000
#            bP-2189O9.1       551.010407
#            bP-2189O9.2       826.518608
#            bP-2189O9.4       137.752692
#            pk              11689.719072
#            yR211F11.2          0.000000
#
#  [34832 rows x 1 columns],                                tpm
#  sample_id gene_name
#  1         A1BG           14.958630
#            A1CF            0.249757
#            A2M             0.000000
#            A2ML1           1.209676
#            A2MP1           0.076626
#            A3GALT2         0.409894
#            A4GALT          0.690401
#            A4GNT           0.000000
#            AAAS            4.978180
#            AACS           21.098401
#            AACSP1          0.468773
#            AADAC           0.000000
#            AADACL2         0.000000
#            AADACL3         0.079934
#            AADACL4         0.305293
#            AADACP1         0.000000
#            AADAT           0.242643
#            AAED1          19.328704
#            AAGAB          35.069570
#            AAK1            6.134148
#            AAMDC          18.129237
#            AAMP           42.022350
#            AANAT           6.493162
#            AAR2            7.624400
#            AARD            1.365747
#            AARS           16.442283
#            AARS2           3.555090
#            AARSD1         51.608180
#            AARSP1          0.000000
#            AASDH           3.564563
#  ...                            ...
#            ZSWIM7          8.230954
#            ZSWIM8        112.787238
#            ZUFSP          58.311290
#            ZW10            1.698065
#            ZWILCH          3.351467
#            ZWINT           0.116129
#            ZXDA            3.723510
#            ZXDB           13.380100
#            ZXDC           11.279710
#            ZYG11A          2.362190
#            ZYG11AP1        0.000000
#            ZYG11B          5.740516
#            ZYX            59.825725
#            ZZEF1          51.838230
#            ZZZ3           26.534556
#            bP-21201H5.1    0.364485
#            bP-21264C1.1    0.619204
#            bP-21264C1.3    0.000000
#            bP-2168N6.1     0.000000
#            bP-2168N6.2     0.000000
#            bP-2168N6.3     0.000000
#            bP-2171C21.2    0.000000
#            bP-2171C21.4    0.000000
#            bP-2171C21.5    4.454740
#            bP-2171C21.6    0.000000
#            bP-2189O9.1     0.709957
#            bP-2189O9.2     0.653762
#            bP-2189O9.4     0.471974
#            pk              4.611100
#            yR211F11.2      0.000000
#
#  [34832 rows x 1 columns])

# %%
np.where(pd.isnull(lengthMat[2]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-be8b7c5f8310> in <module>()
# ----> 1 np.where(pd.isnull(lengthMat[2]))
#
# /home/maxim/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /home/maxim/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /home/maxim/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /home/maxim/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/maxim/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 2

# %% [markdown]
# ^^ above scaling was abandoned for now.
#
# download another dataset and process:

# %%
# !gsutil ls gs://mz-hammerlab/output/
# Out:
# gs://mz-hammerlab/output/
# gs://mz-hammerlab/output/ERR431566.logs.tar.gz
# gs://mz-hammerlab/output/ERR431566.tar.gz
# gs://mz-hammerlab/output/ERR431567.logs.tar.gz
# gs://mz-hammerlab/output/ERR431567.tar.gz
# gs://mz-hammerlab/output/ERR431568.logs.tar.gz
# gs://mz-hammerlab/output/ERR431568.tar.gz
# gs://mz-hammerlab/output/ERR431569.logs.tar.gz
# gs://mz-hammerlab/output/ERR431569.tar.gz
# gs://mz-hammerlab/output/ERR431570.logs.tar.gz
# gs://mz-hammerlab/output/ERR431570.tar.gz
# gs://mz-hammerlab/output/ERR431571.logs.tar.gz
# gs://mz-hammerlab/output/ERR431571.tar.gz
# gs://mz-hammerlab/output/ERR431572.logs.tar.gz
# gs://mz-hammerlab/output/ERR431572.tar.gz
# gs://mz-hammerlab/output/ERR431573.logs.tar.gz
# gs://mz-hammerlab/output/ERR431573.tar.gz
# gs://mz-hammerlab/output/ERR431574.logs.tar.gz
# gs://mz-hammerlab/output/ERR431574.tar.gz
# gs://mz-hammerlab/output/ERR431575.logs.tar.gz
# gs://mz-hammerlab/output/ERR431575.tar.gz
# gs://mz-hammerlab/output/ERR431576.logs.tar.gz
# gs://mz-hammerlab/output/ERR431576.tar.gz
# gs://mz-hammerlab/output/ERR431577.logs.tar.gz
# gs://mz-hammerlab/output/ERR431577.tar.gz
# gs://mz-hammerlab/output/ERR431578.logs.tar.gz
# gs://mz-hammerlab/output/ERR431578.tar.gz
# gs://mz-hammerlab/output/ERR431579.logs.tar.gz
# gs://mz-hammerlab/output/ERR431579.tar.gz
# gs://mz-hammerlab/output/ERR431580.logs.tar.gz
# gs://mz-hammerlab/output/ERR431580.tar.gz
# gs://mz-hammerlab/output/ERR431581.logs.tar.gz
# gs://mz-hammerlab/output/ERR431581.tar.gz
# gs://mz-hammerlab/output/ERR431582.logs.tar.gz
# gs://mz-hammerlab/output/ERR431582.tar.gz
# gs://mz-hammerlab/output/ERR431583.logs.tar.gz
# gs://mz-hammerlab/output/ERR431583.tar.gz
# gs://mz-hammerlab/output/ERR431584.logs.tar.gz
# gs://mz-hammerlab/output/ERR431584.tar.gz
# gs://mz-hammerlab/output/ERR431585.logs.tar.gz
# gs://mz-hammerlab/output/ERR431585.tar.gz
# gs://mz-hammerlab/output/ERR431586.logs.tar.gz
# gs://mz-hammerlab/output/ERR431586.tar.gz
# gs://mz-hammerlab/output/ERR431587.logs.tar.gz
# gs://mz-hammerlab/output/ERR431587.tar.gz
# gs://mz-hammerlab/output/ERR431588.logs.tar.gz
# gs://mz-hammerlab/output/ERR431588.tar.gz
# gs://mz-hammerlab/output/ERR431589.logs.tar.gz
# gs://mz-hammerlab/output/ERR431589.tar.gz
# gs://mz-hammerlab/output/ERR431590.logs.tar.gz
# gs://mz-hammerlab/output/ERR431590.tar.gz
# gs://mz-hammerlab/output/ERR431591.logs.tar.gz
# gs://mz-hammerlab/output/ERR431591.tar.gz
# gs://mz-hammerlab/output/ERR431592.logs.tar.gz
# gs://mz-hammerlab/output/ERR431592.tar.gz
# gs://mz-hammerlab/output/ERR431593.logs.tar.gz
# gs://mz-hammerlab/output/ERR431593.tar.gz
# gs://mz-hammerlab/output/ERR431594.logs.tar.gz
# gs://mz-hammerlab/output/ERR431594.tar.gz
# gs://mz-hammerlab/output/ERR431595.logs.tar.gz
# gs://mz-hammerlab/output/ERR431595.tar.gz
# gs://mz-hammerlab/output/ERR431596.logs.tar.gz
# gs://mz-hammerlab/output/ERR431596.tar.gz
# gs://mz-hammerlab/output/ERR431597.logs.tar.gz
# gs://mz-hammerlab/output/ERR431597.tar.gz
# gs://mz-hammerlab/output/ERR431598.logs.tar.gz
# gs://mz-hammerlab/output/ERR431598.tar.gz
# gs://mz-hammerlab/output/ERR431599.logs.tar.gz
# gs://mz-hammerlab/output/ERR431599.tar.gz
# gs://mz-hammerlab/output/ERR431600.logs.tar.gz
# gs://mz-hammerlab/output/ERR431600.tar.gz
# gs://mz-hammerlab/output/ERR431601.logs.tar.gz
# gs://mz-hammerlab/output/ERR431601.tar.gz
# gs://mz-hammerlab/output/ERR431602.logs.tar.gz
# gs://mz-hammerlab/output/ERR431602.tar.gz
# gs://mz-hammerlab/output/ERR431603.logs.tar.gz
# gs://mz-hammerlab/output/ERR431603.tar.gz
# gs://mz-hammerlab/output/ERR431604.logs.tar.gz
# gs://mz-hammerlab/output/ERR431604.tar.gz
# gs://mz-hammerlab/output/ERR431605.logs.tar.gz
# gs://mz-hammerlab/output/ERR431605.tar.gz
# gs://mz-hammerlab/output/ERR431606.logs.tar.gz
# gs://mz-hammerlab/output/ERR431606.tar.gz
# gs://mz-hammerlab/output/ERR431607.logs.tar.gz
# gs://mz-hammerlab/output/ERR431607.tar.gz
# gs://mz-hammerlab/output/ERR431608.logs.tar.gz
# gs://mz-hammerlab/output/ERR431608.tar.gz
# gs://mz-hammerlab/output/ERR431609.logs.tar.gz
# gs://mz-hammerlab/output/ERR431609.tar.gz
# gs://mz-hammerlab/output/ERR431610.logs.tar.gz
# gs://mz-hammerlab/output/ERR431610.tar.gz
# gs://mz-hammerlab/output/ERR431611.logs.tar.gz
# gs://mz-hammerlab/output/ERR431611.tar.gz
# gs://mz-hammerlab/output/ERR431612.logs.tar.gz
# gs://mz-hammerlab/output/ERR431612.tar.gz
# gs://mz-hammerlab/output/ERR431613.logs.tar.gz
# gs://mz-hammerlab/output/ERR431613.tar.gz
# gs://mz-hammerlab/output/ERR431614.logs.tar.gz
# gs://mz-hammerlab/output/ERR431614.tar.gz
# gs://mz-hammerlab/output/ERR431615.logs.tar.gz
# gs://mz-hammerlab/output/ERR431615.tar.gz
# gs://mz-hammerlab/output/ERR431616.logs.tar.gz
# gs://mz-hammerlab/output/ERR431616.tar.gz
# gs://mz-hammerlab/output/ERR431617.logs.tar.gz
# gs://mz-hammerlab/output/ERR431617.tar.gz
# gs://mz-hammerlab/output/ERR431618.logs.tar.gz
# gs://mz-hammerlab/output/ERR431618.tar.gz
# gs://mz-hammerlab/output/ERR431619.logs.tar.gz
# gs://mz-hammerlab/output/ERR431619.tar.gz
# gs://mz-hammerlab/output/ERR431620.logs.tar.gz
# gs://mz-hammerlab/output/ERR431620.tar.gz
# gs://mz-hammerlab/output/ERR431621.logs.tar.gz
# gs://mz-hammerlab/output/ERR431621.tar.gz
# gs://mz-hammerlab/output/ERR431622.logs.tar.gz
# gs://mz-hammerlab/output/ERR431622.tar.gz
# gs://mz-hammerlab/output/ERR431623.logs.tar.gz
# gs://mz-hammerlab/output/ERR431623.tar.gz
# gs://mz-hammerlab/output/ERR431624.logs.tar.gz
# gs://mz-hammerlab/output/ERR431624.tar.gz
# gs://mz-hammerlab/output/ERR431625.logs.tar.gz
# gs://mz-hammerlab/output/ERR431625.tar.gz
# gs://mz-hammerlab/output/ERR431626.logs.tar.gz
# gs://mz-hammerlab/output/ERR431626.tar.gz
# gs://mz-hammerlab/output/ERR431627.logs.tar.gz
# gs://mz-hammerlab/output/ERR431627.tar.gz
# gs://mz-hammerlab/output/ERR431628.logs.tar.gz
# gs://mz-hammerlab/output/ERR431628.tar.gz

# %%
# !gsutil cp gs://mz-hammerlab/output/ERR431624.tar.gz .;
# !gsutil cp gs://mz-hammerlab/output/ERR431624.logs.tar.gz .;
# !tar -zxvf ERR431624.tar.gz && rm ERR431624.tar.gz;
# !tar -zxvf ERR431624.logs.tar.gz && rm ERR431624.logs.tar.gz;
# Out:
# Copying gs://mz-hammerlab/output/ERR431624.tar.gz...
# Downloading file://./ERR431624.tar.gz:                           22.66 MiB/22.66 MiB
# Copying gs://mz-hammerlab/output/ERR431624.logs.tar.gz...
# Downloading file://./ERR431624.logs.tar.gz:                      265.74 KiB/265.74 KiB
# output/ERR431624/
# output/ERR431624/abundance.tsv
# output/ERR431624/abundance.h5
# output/ERR431624/run_info.json
# logs/ERR431624/out.txt
# logs/ERR431624/sar.txt
# logs/ERR431624/time.txt

# %%
def download(s):
    # !gsutil cp gs://mz-hammerlab/output/"$s".tar.gz .;
    # !gsutil cp gs://mz-hammerlab/output/"$s".logs.tar.gz .;
    # !tar -zxvf "$s".tar.gz && rm "$s".tar.gz;
    # !tar -zxvf "$s".logs.tar.gz && rm "$s".logs.tar.gz;
    print 'downloaded', s
download('ERR431583')
# Out:
# Copying gs://mz-hammerlab/output/ERR431583.tar.gz...
# Downloading file://./ERR431583.tar.gz:                           24.53 MiB/24.53 MiB
# Copying gs://mz-hammerlab/output/ERR431583.logs.tar.gz...
# Downloading file://./ERR431583.logs.tar.gz:                      448.12 KiB/448.12 KiB
# output/ERR431583/
# output/ERR431583/abundance.tsv
# output/ERR431583/abundance.h5
# output/ERR431583/run_info.json
# logs/ERR431583/out.txt
# logs/ERR431583/sar.txt
# logs/ERR431583/time.txt
# downloaded ERR431583

# %%
# !ls -l output
# Out:
# total 16
# drwxr-xr-x 2 maxim maxim 4096 Jul 29 21:31 ERR431572
# drwxr-xr-x 2 maxim maxim 4096 Jul 29 23:40 ERR431583
# drwxrwxr-x 2 maxim maxim 4096 Aug  2 15:40 ERR431617
# drwxr-xr-x 2 maxim maxim 4096 Jul 31 19:53 ERR431624

# %%
from pyensembl import cached_release
ensembl_release = cached_release(79)
def load_multiple(files):
    """
    files is ordered list of samples. they will be assigned sample ids 1-n.
    """
    dfs = []
    for ix, f in enumerate(files):
        df = pd.read_csv('data/output/%s/abundance.tsv' % f, sep='\t')
        df['sample_id'] = ix+1
        df['gene_name'] = df['target_id'].map(lambda t: ensembl_release.gene_name_of_transcript_id(t))
        dfs.append(df)
    return pd.concat(dfs)
        
def simple_summary(df):
    """
    sum counts, abundance (tpm) across genes
    """
    return df.groupby(['sample_id', 'gene_name'])[['est_counts', 'tpm']].sum().reset_index()

# %%
# process both B cells
simple_summary = simple_summary(load_multiple(['ERR431572', 'ERR431624', 'ERR431583']))
simple_summary.head()
# Out:
#    sample_id gene_name  est_counts        tpm
# 0          1      A1BG   80.232280  11.155641
# 1          1      A1CF   18.042401   0.382263
# 2          1       A2M    3.000000   1.226161
# 3          1     A2ML1   21.912401   2.756862
# 4          1     A2MP1    2.000000   0.092441

# %%
simple_summary.tail()
# Out:
#         sample_id    gene_name  est_counts       tpm
# 104491          3  bP-2189O9.1    0.000000  0.000000
# 104492          3  bP-2189O9.2    3.263100  0.347490
# 104493          3  bP-2189O9.4    0.000000  0.000000
# 104494          3           pk   63.556597  2.080726
# 104495          3   yR211F11.2    2.000000  0.715197

# %%
simple_summary.to_csv('data/summary.simple.tsv', sep='\t', index=None)

# %% [markdown]
# ## A quick look at all the datafiles we have

# %%
datafiles = pd.read_csv('data_filenames.tsv', sep='\t')
datafiles[['filename', 'SubSet', 'Antibody']]
# Out:
#      filename               SubSet                            Antibody
# 0   ERR431599                B_CD5                          CD19+,CD5+
# 1   ERR431596                B_CD5                          CD19+,CD5+
# 2   ERR431591                B_CD5                          CD19+,CD5+
# 3   ERR431568                B_CD5                          CD19+,CD5+
# 4   ERR431617             B_Memory                    CD19+,CD5-,CD27+
# 5   ERR431569             B_Memory                    CD19+,CD5-,CD27+
# 6   ERR431594             B_Memory                    CD19+,CD5-,CD27+
# 7   ERR431613             B_Memory                    CD19+,CD5-,CD27+
# 8   ERR431608             B_Memory                    CD19+,CD5-,CD27+
# 9   ERR431572              B_Naive                    CD19+,CD5-,CD27-
# 10  ERR431624              B_Naive                    CD19+,CD5-,CD27-
# 11  ERR431619              B_Naive                    CD19+,CD5-,CD27-
# 12  ERR431586              B_Naive                    CD19+,CD5-,CD27-
# 13  ERR431611              B_Naive                    CD19+,CD5-,CD27-
# 14  ERR431582   CD4_Central_Memory  CD4+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 15  ERR431626   CD4_Central_Memory  CD4+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 16  ERR431620   CD4_Central_Memory  CD4+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 17  ERR431614   CD4_Central_Memory  CD4+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 18  ERR431598   CD4_Central_Memory  CD4+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 19  ERR431576  CD4_Effector_Memory  CD4+,CCR7-,CD45RA-,CD45RO+,CD45RO+
# 20  ERR431603  CD4_Effector_Memory  CD4+,CCR7-,CD45RA-,CD45RO+,CD45RO+
# 21  ERR431616  CD4_Effector_Memory  CD4+,CCR7-,CD45RA-,CD45RO+,CD45RO+
# 22  ERR431575  CD4_Effector_Memory  CD4+,CCR7-,CD45RA-,CD45RO+,CD45RO+
# 23  ERR431588  CD4_Effector_Memory  CD4+,CCR7-,CD45RA-,CD45RO+,CD45RO+
# 24  ERR431580            CD4_Naive  CD4+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 25  ERR431610            CD4_Naive  CD4+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 26  ERR431571            CD4_Naive  CD4+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 27  ERR431581            CD4_Naive  CD4+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 28  ERR431574            CD4_Naive  CD4+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 29  ERR431622              CD4_Th1                         CD4+,CXCR3+
# ..        ...                  ...                                 ...
# 33  ERR431587              CD4_Th1                         CD4+,CXCR3+
# 34  ERR431597             CD4_Th17     CD4+,CCR6+,CD161+,CXCR3-,CXCR3-
# 35  ERR431625             CD4_Th17     CD4+,CCR6+,CD161+,CXCR3-,CXCR3-
# 36  ERR431604             CD4_Th17     CD4+,CCR6+,CD161+,CXCR3-,CXCR3-
# 37  ERR431595             CD4_Th17     CD4+,CCR6+,CD161+,CXCR3-,CXCR3-
# 38  ERR431618             CD4_Th17     CD4+,CCR6+,CD161+,CXCR3-,CXCR3-
# 39  ERR431628              CD4_Th2                  CD4+,CRTH2+,CXCR3-
# 40  ERR431579              CD4_Th2                  CD4+,CRTH2+,CXCR3-
# 41  ERR431600              CD4_Th2                  CD4+,CRTH2+,CXCR3-
# 42  ERR431566              CD4_Th2                  CD4+,CRTH2+,CXCR3-
# 43  ERR431615              CD4_Th2                  CD4+,CRTH2+,CXCR3-
# 44  ERR431583             CD4_Treg                   CD4+,CD127-,CD25+
# 45  ERR431606             CD4_Treg                   CD4+,CD127-,CD25+
# 46  ERR431609             CD4_Treg                   CD4+,CD127-,CD25+
# 47  ERR431601             CD4_Treg                   CD4+,CD127-,CD25+
# 48  ERR431589             CD4_Treg                   CD4+,CD127-,CD25+
# 49  ERR431607   CD8_Central_Memory  CD8+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 50  ERR431578   CD8_Central_Memory  CD8+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 51  ERR431593   CD8_Central_Memory  CD8+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 52  ERR431602   CD8_Central_Memory  CD8+,CCR7+,CD45RA-,CD45RO+,CD45RO+
# 53  ERR431621         CD8_Effector          CD8+,CCR7-,CD45RA-,CD45RO+
# 54  ERR431585         CD8_Effector          CD8+,CCR7-,CD45RA-,CD45RO+
# 55  ERR431573         CD8_Effector          CD8+,CCR7-,CD45RA-,CD45RO+
# 56  ERR431590         CD8_Effector          CD8+,CCR7-,CD45RA-,CD45RO+
# 57  ERR431567         CD8_Effector          CD8+,CCR7-,CD45RA-,CD45RO+
# 58  ERR431612            CD8_Naive  CD8+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 59  ERR431605            CD8_Naive  CD8+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 60  ERR431623            CD8_Naive  CD8+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 61  ERR431627            CD8_Naive  CD8+,CCR7+,CD45RA+,CD45RO-,CD45RO-
# 62  ERR431592            CD8_Naive  CD8+,CCR7+,CD45RA+,CD45RO-,CD45RO-
#
# [63 rows x 3 columns]

# %%
datafiles[datafiles.SubSet.str.lower().str.contains('treg')]
# Out:
#      Source       Name    SubSet           Antibody  InnerSize  \
# 44  SQ_0021  ERS403436  CD4_Treg  CD4+,CD127-,CD25+        450
# 45  SQ_0022  ERS403386  CD4_Treg  CD4+,CD127-,CD25+        450
# 46  SQ_0023  ERS403435  CD4_Treg  CD4+,CD127-,CD25+        450
# 47  SQ_0065  ERS403410  CD4_Treg  CD4+,CD127-,CD25+        449
# 48  SQ_0067  ERS403428  CD4_Treg  CD4+,CD127-,CD25+        444
#
#                                                R1 URI  \
# 44  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 45  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 46  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 47  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 48  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
#
#                            R1 MD5SUM  \
# 44  1f30880aa773dcc912b2e7c6db2ae6fe
# 45  b9fd31742d7a4eff1790982a64795146
# 46  c3435337bcee5dad1524d6af609f47f3
# 47  8aae8956187b8fdfd0ba12701feb173b
# 48  d36596f9f35d041225666659e6494cf7
#
#                                                R2 URI  \
# 44  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 45  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 46  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 47  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
# 48  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR431/ERR4...
#
#                            R2 MD5SUM   filename
# 44  c5d9d48830eb5d183b6ce080b6a329b2  ERR431583
# 45  ebc1489184defb91e5b8814123413152  ERR431606
# 46  66bf895e7b84440297bea97b2aaa07e1  ERR431609
# 47  6b42df8aa6924553d2f40de84eead826  ERR431601
# 48  8fa326a4a158bcec4c5e9adc2f12316c  ERR431589
