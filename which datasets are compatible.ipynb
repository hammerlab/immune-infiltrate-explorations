# %% [markdown]
# Looking at raw datasets.

# %%
# %load ~/ipyhead
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
#abbas = pd.read_csv('curated_data/pure_samples/abbas/GSE11103_matrix_pure.txt', sep='\t')
# see annotate.R in that directory
abbas = pd.read_csv('curated_data/pure_samples/abbas/abbas.pure.ann.csv')
abbas.head()
# Out:
#    Row.names  ACCNUM  SYMBOL                                          DESC  \
# 1  1007_s_at  U48705     NaN                                           NaN
# 2    1053_at  M87338    RFC2                replication factor C subunit 2
# 3     117_at  X51757   HSPA6  heat shock protein family A (Hsp70) member 6
# 4     121_at  X69699    PAX8                                  paired box 8
# 5  1255_g_at  L36861  GUCA1A                guanylate cyclase activator 1A
#
#   X.Sample_title  PRB12534.Jurkat  PRB12535.Jurkat  PRB12536.Jurkat  \
# 1      1007_s_at          467.497          285.915          271.789
# 2        1053_at         2104.464         1913.695         1974.465
# 3         117_at          189.528          110.972          160.200
# 4         121_at         1753.889         1291.766         1885.517
# 5      1255_g_at           19.085           12.050           60.760
#
#    PRB12537.IM.9  PRB12538.IM.9  PRB12539.IM.9  PRB12540.Raji  PRB12541.Raji  \
# 1        422.933        275.588        318.546       1310.795       1671.770
# 2       2428.428       2232.343       2470.156        831.009        713.614
# 3        432.932        261.238        280.899        184.187        178.548
# 4       1561.437       1534.517       1540.394       1666.894       1625.360
# 5         15.171         56.276         16.242         45.300         55.810
#
#    PRB12542.Raji  PRB12543.THP.1  PRB12544.THP.1  PRB12545.THP.1
# 1       1349.464         260.005         178.772         190.054
# 2       1164.667        1658.769        1290.185        1516.727
# 3        158.211         216.398         202.340         187.029
# 4       1860.036        1975.209        1423.538        1748.505
# 5         49.121          30.585          39.566          25.296

# %%
cibersort = pd.read_csv('curated_data/pure_samples/cibersort/LM22-ref-sample.txt', sep='\t')
cibersort.head()
# Out:
#   Relabel  A_LW_+BAFF_U133A_250303 [Chtanova_immune|A_LW_+BAFF_U133A_250303]  \
# 0    A1CF                                         123.126291
# 1     A2M                                           6.717625
# 2  A4GALT                                          99.776993
# 3   A4GNT                                         155.687079
# 4    AAAS                                          11.966722
#
#    A_LW_+BAFF_U133A_70303 [Chtanova_immune|A_LW_+BAFF_U133A_70303]  \
# 0                                         200.096593
# 1                                          20.118036
# 2                                          56.050865
# 3                                         277.949173
# 4                                          20.671809
#
#    A_LW_-BAFF_U133A_250303 [Chtanova_immune|A_LW_-BAFF_U133A_250303]  \
# 0                                          98.131873
# 1                                          66.069727
# 2                                          52.735724
# 3                                         186.486014
# 4                                          25.856604
#
#    A_LW_-BAFF_U133A_70303 [Chtanova_immune|A_LW_-BAFF_U133A_70303]  \
# 0                                         101.011423
# 1                                          92.850207
# 2                                          62.908979
# 3                                         147.002254
# 4                                           9.910548
#
#    A_LW_CD57+_U133A_030603 [Chtanova_immune|A_LW_CD57+_U133A_030603]  \
# 0                                         127.567885
# 1                                          56.525064
# 2                                         115.173360
# 3                                         165.954151
# 4                                         126.638097
#
#    A_LW_CD57+_U133A_121102 [Chtanova_immune|A_LW_CD57+_U133A_121102]  \
# 0                                         109.295918
# 1                                          11.575293
# 2                                          86.849782
# 3                                         102.583059
# 4                                          24.107794
#
#    A_LW_CD57-_U133A_030603 [Chtanova_immune|A_LW_CD57-_U133A_030603]  \
# 0                                          48.352882
# 1                                          73.481899
# 2                                          67.478214
# 3                                          95.945725
# 4                                         159.323152
#
#    A_LW_CD57-_U133A_121102 [Chtanova_immune|A_LW_CD57-_U133A_121102]  \
# 0                                         328.453377
# 1                                          31.083799
# 2                                         172.369277
# 3                                         231.328049
# 4                                          35.289550
#
#    A_LW_DC+BAFF_U133A_250304 [Chtanova_immune|A_LW_DC+BAFF_U133A_250304]  \
# 0                                         370.158338
# 1                                        8579.063240
# 2                                         112.346538
# 3                                         151.153031
# 4                                          20.363367
#
#                  ...                 TEM_U133A_1 [TFH_E-MEXP-750|TEM_U133A_1]  \
# 0                ...                                                27.752002
# 1                ...                                                10.950348
# 2                ...                                                22.164461
# 3                ...                                               127.732540
# 4                ...                                               216.557256
#
#    TEM_U133A_2 [TFH_E-MEXP-750|TEM_U133A_2]  \
# 0                                 81.227451
# 1                                  6.779301
# 2                                 41.200690
# 3                                100.458390
# 4                                108.114573
#
#    TEM_U133A_3 [TFH_E-MEXP-750|TEM_U133A_3]  \
# 0                                 25.180355
# 1                                 85.101667
# 2                                 24.504919
# 3                                341.302205
# 4                                126.690956
#
#    TN_U133A_1 [TFH_E-MEXP-750|TN_U133A_1]  \
# 0                              285.075510
# 1                               18.227925
# 2                              145.190417
# 3                              411.623288
# 4                              423.425075
#
#    TN_U133A_2 [TFH_E-MEXP-750|TN_U133A_2]  \
# 0                              172.215727
# 1                               16.924983
# 2                              135.992279
# 3                              216.770728
# 4                              162.619165
#
#    TN_U133A_3 [TFH_E-MEXP-750|TN_U133A_3]  TH_1 [TREGs_GSE4527|GSM101518]  \
# 0                              201.051021                      736.149237
# 1                                9.039432                      129.643861
# 2                               62.335556                      232.214201
# 3                              141.512782                      384.736274
# 4                              151.616733                       96.051241
#
#    Treg_1 [TREGs_GSE4527|GSM101519]  TH_2 [TREGs_GSE4527|GSM101520]  \
# 0                        400.456332                      187.566155
# 1                         75.252245                       28.603811
# 2                        335.890507                      207.934712
# 3                        510.736942                      203.089268
# 4                        176.780559                      248.657488
#
#    Treg_2 [TREGs_GSE4527|GSM101521]
# 0                        414.069368
# 1                         22.338213
# 2                         56.080230
# 3                        539.912283
# 4                         89.153691
#
# [5 rows x 195 columns]

# %%
# see process.R in that directory for how we generated files
bindea = pd.read_csv('curated_data/pure_samples/bindea/data.ann.csv')
bindea.head()
# Out:
#    Row.names  ACCNUM  SYMBOL                                          DESC  \
# 1  1007_s_at  U48705     NaN                                           NaN
# 2    1053_at  M87338    RFC2                replication factor C subunit 2
# 3     117_at  X51757   HSPA6  heat shock protein family A (Hsp70) member 6
# 4     121_at  X69699    PAX8                                  paired box 8
# 5  1255_g_at  L36861  GUCA1A                guanylate cyclase activator 1A
#
#    GSM155229.CEL.gz  GSM155232.CEL.gz  GSM155234.CEL.gz  GSM155236.CEL.gz  \
# 1          6.275143          6.358719          6.416320          6.517430
# 2          5.379340          5.478169          5.244693          5.466399
# 3          5.482636          5.445851          5.588545          5.048590
# 4          7.839799          8.059975          7.976771          8.045602
# 5          3.218793          3.184714          3.339109          3.338531
#
#    GSM155238.CEL.gz  GSM21712.CEL.gz        ...          CSS_COLON_N_20.CEL  \
# 1          6.485500         7.700334        ...                    8.645079
# 2          5.343193         7.062141        ...                    5.100465
# 3          5.298323         5.274389        ...                    5.243623
# 4          7.874164         8.540705        ...                    7.937146
# 5          3.269852         3.189743        ...                    3.239869
#
#    CSS_COLON_N_21.CEL  CSS_COLON_N_22.CEL  CSS_COLON_N_23.CEL  \
# 1            8.641939            8.253738            7.995270
# 2            5.098031            4.829341            5.249402
# 3            5.602255            5.313883            5.095599
# 4            7.861328            7.766241            7.843206
# 5            3.739132            3.184358            2.992740
#
#    CSS_COLON_N_3.CEL  CSS_COLON_N_4.CEL  CSS_COLON_N_5.CEL  CSS_COLON_N_6.CEL  \
# 1           7.663437           7.550225           7.130000           7.945850
# 2           5.062541           5.151866           4.922264           4.939676
# 3           5.953039           5.609692           5.248816           5.136005
# 4           7.376945           7.922368           7.682052           7.325137
# 5           3.895404           3.423051           3.203903           3.060464
#
#    CSS_COLON_N_7.CEL  CSS_COLON_N_9.CEL
# 1           6.528113           7.533900
# 2           5.313122           5.162694
# 3           5.461077           5.689058
# 4           7.196305           7.243131
# 5           3.173166           4.306242
#
# [5 rows x 71 columns]

# %% [markdown]
# # find intersections
#
# Decent intersection between bindea and cibersort and between abbas and cibersort! (by gene name)
#
# Decent intersection between abbas and bindea! (by probe ID)

# %%
# sanity check of intersect operation
assert len(set(cibersort[cibersort.columns[0]]) & set(cibersort[cibersort.columns[0]])) == len(cibersort)

# %%
set(abbas[abbas.columns[0]]) & set(cibersort[cibersort.columns[0]])
# Out:
# set()

# %%
set(bindea[bindea.columns[0]]) & set(cibersort[cibersort.columns[0]])
# Out:
# set()

# %%
len(set(bindea[bindea.columns[2]]) & set(cibersort[cibersort.columns[0]])), len(bindea), len(cibersort)
# Out:
# (10977, 22283, 11866)

# %%
len(set(abbas[abbas.columns[2]]) & set(cibersort[cibersort.columns[0]])), len(abbas), len(cibersort)
# Out:
# (10977, 54681, 11866)

# %%
len(set(abbas[abbas.columns[0]]) & set(bindea[bindea.columns[0]])), len(abbas), len(bindea)
# Out:
# (22283, 54681, 22283)
